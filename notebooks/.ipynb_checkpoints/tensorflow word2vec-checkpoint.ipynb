# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    local_filename = os.path.join(gettempdir(), filename)
    if not os.path.exists(local_filename):
        local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
    statinfo = os.stat(local_filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
    return local_filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
filename = "../data/abstracts.txt"
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with open(filename, 'r') as f:
        data = (f.read().split())
    return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 7438

# %%
vocabulary_size = 2849

# %%
def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# %%
# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 1], ('the', 397), ('of', 322), ('and', 249), ('in', 139)]
# Sample data [21, 154, 805, 329, 2, 50, 435, 18, 153, 20] ['We', 'demonstrate', 'automated', 'generation', 'of', 'diffusion', 'databases', 'from', 'high-throughput', 'density']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    if data_index + span > len(data):
        data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
        context_words = [w for w in range(span) if w != skip_window]
        words_to_use = random.sample(context_words, num_skips)
        for j, context_word in enumerate(words_to_use):
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[context_word]
        if data_index == len(data):
            for word in data[:span]:
                buffer.append(word)
            data_index = span
        else:
            buffer.append(data[data_index])
            data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 1 the -> 2445 latter
# 1 the -> 5 for
# 2445 latter -> 1 the
# 2445 latter -> 302 one
# 302 one -> 25 an
# 302 one -> 2445 latter
# 25 an -> 302 one
# 25 an -> 2660 alternative

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 4       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # Explanation of the meaning of NCE loss:
    #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  181.468353271
# Nearest to provide: shells, enabling, Several, lowest, anionicity,, tagged, individual, specific,
# Nearest to using: SW480,, link, (selected, coarse-grain, significantly, difficult, merit, API),
# Nearest to than: (SBUs), phases, van, behavior., Further,, (5);, conundrum,, reports,
# Nearest to analysis: scripts, PAW, out, principles, proceeds, It, Compositions, SoluteEffects.csv,
# Nearest to well: distribution, cohesion, connecting, discuss, M, high, observations, 3),
# Nearest to a: accompanies, have, calculations., filesSteel, appropriate, simulations,, best, pseudopotential,
# Nearest to by: population, Starting, highlights, 1.9%., compiled, (visualization/visualization.ipynb')We, boundary, Award,
# Nearest to values: Recommended, methodology, absorption, Harris−Foulkes, dataThis, infra-red, SP-100, Provide,
# Nearest to properties: nanoporous, embrittlement, biaxial, relatively, tail, Blöchl’s, fully-relativistic, characteristics,
# Nearest to all: Located, Sept., charge, Machine-learning, essential, (CS),, Physics, Cp*W(NO)(H)(η1-CH2CH═CMe2)(PMe3).Welcome,
# Nearest to on: (called, described, (PAB), solution., zip, dawn, energies., crystallographically.,
# Nearest to DFT: significant, principal, physics,, API, POTCAR, motifs, change, (CE),
# Nearest to based: (fcc), Pure-phase, eV, catalysis,, titled, insight.The, room, continuum,
# Nearest to both: led, record, remain, study”, (https://github.com/vilab-tartu/SCAN), 0.3,, integration, simplicity,
# Nearest to For: learning, Spectroscopy, To, (0D), interesting, materials,, X., accompanied,
# Nearest to the: distributions, radii, http://trc.nist.gov/.This, package., composites", automatically, reports, ferroelectric,
# Average loss at step  2000 :  15.0439515321
# Average loss at step  4000 :  4.3757341243
# Average loss at step  6000 :  3.97714554882
# Average loss at step  8000 :  3.7046825484
# Average loss at step  10000 :  3.50463238299
# Nearest to provide: enabling, Several, shells, specific, individual, anionicity,, lowest, report,
# Nearest to using: SW480,, Search, measurement, coarse-grain, link, (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., (selected, non-magnetic,
# Nearest to than: (SBUs), Further,, reports, as:, conundrum,, Au12,, phases, Struct,
# Nearest to analysis: scripts, Compositions, It, proceeds, C7O2H10, out, principles, PAW,
# Nearest to well: distribution, connecting, applications., M, as, Ti,, cohesion, (JARVIS-ML),
# Nearest to a: feasible,, accompanies, already, broad, inherently, photovoltaic, submitted, best,
# Nearest to by: Award, population, prohibit, Starting, calculating, XAS-Data-Interchange, repository, disseminating,
# Nearest to values: Recommended, dataThis, oxide, methodology, quasiparticle, absorption, infra-red, Provide,
# Nearest to properties: nanoporous, embrittlement, characteristics, fully-relativistic, Blöchl’s, plane, Zenobia, tail,
# Nearest to all: Cp*W(NO)(H)(η1-CH2CH═CMe2)(PMe3).Welcome, modeling, (CS),, Located, Machine-learning, platinum, Large, brute,
# Nearest to on: degree, solution., zip, 4, Observatory, [Pt­(C^N)­(CN)2M­(PPh3)2]2, High-resolution, JCAP's,
# Nearest to DFT: significant, produce, physics,, motifs, electrocatalysts, change, API, Vienna,
# Nearest to based: catalysis,, Supporting, Pure-phase, unary,, annealing, is:, minimizes, titled,
# Nearest to both: led, remain, 0.3,, study”, QM9), multi-frequency, Xu1,, structure,,
# Nearest to For: interesting, To, learning, materials,, accompanied, nm)., (0D), convenience,
# Nearest to the: Normal.py, ASTM, (MatChS), sampled, convention, fitting, materials,, electronegativities,,
# Average loss at step  12000 :  3.3540248493
# Average loss at step  14000 :  3.23822318017
# Average loss at step  16000 :  3.14904134381
# Average loss at step  18000 :  3.07170492417
# Average loss at step  20000 :  3.01750667399
# Nearest to provide: enabling, Several, certain, predictions., highlighting, report, ferrite., anionicity,,
# Nearest to using: SW480,, measurement, (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., coarse-grain, (selected, Search, non-magnetic, link,
# Nearest to than: (SBUs), Struct, Au12,, 2400, Further,, as:, calibration, behavior.,
# Nearest to analysis: scripts, Compositions, PBE, proceeds, Also, latex, out, C7O2H10,
# Nearest to well: distribution, connecting, applications., as, twin., access;, Ti,, Cubic,
# Nearest to a: already, feasible,, broad, photovoltaic, submitted, accompanies, inherently, Starting,
# Nearest to by: Award, calculating, population, Starting, achieved, XAS-Data-Interchange, repository, resulting,
# Nearest to values: Recommended, dataThis, infra-red, Australian, oxide, methodology, provenance, quasiparticle,
# Nearest to properties: nanoporous, Blöchl’s, plane, coordination, strengths, Zenobia, characteristics, fully-relativistic,
# Nearest to all: Cp*W(NO)(H)(η1-CH2CH═CMe2)(PMe3).Welcome, modeling, brute, Located, platinum, essential, suitable, Large,
# Nearest to on: degree, solution., 4, based, substance, zip, [Pt­(C^N)­(CN)2M­(PPh3)2]2, Observatory,
# Nearest to DFT: electrocatalysts, produce, motifs, Vienna, evaluated., change, physics,, counterion,
# Nearest to based: catalysis,, Supporting, annealing, Pure-phase, unary,, is:, on, minimizes,
# Nearest to both: led, remain, QM9), Xu1,, multi-frequency, sensing, 0.3,, study”,
# Nearest to For: interesting, convenience, hcp, accompanied, MEAM,, nm)., To, (0D),
# Nearest to the: (MatChS), seconds., ASTM, Normal.py, sampled, electronegativities,, package., bulk.,
# Average loss at step  22000 :  2.9721444115
# Average loss at step  24000 :  2.93151266718
# Average loss at step  26000 :  2.89885778874
# Average loss at step  28000 :  2.87717280704
# Average loss at step  30000 :  2.85530092549
# Nearest to provide: enabling, Several, certain, database:, predictions., page, report, highlighting,
# Nearest to using: SW480,, coarse-grain, measurement, (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., (selected, non-magnetic, Search, plane-wave,
# Nearest to than: 2400, Au12,, calibration, generation, Struct, estimate, as:, (SBUs),
# Nearest to analysis: scripts, Compositions, Also, latex, (1D), proceeds, PBE, electrocatalysts,
# Nearest to well: distribution, applications., connecting, as, twin., access;, Cubic, cohesion,
# Nearest to a: broad, already, feasible,, Starting, photovoltaic, agree, submitted, accompanies,
# Nearest to by: Award, calculating, XAS-Data-Interchange, Starting, resulting, population, achieved, repository,
# Nearest to values: Recommended, Australian, dataThis, infra-red, provenance, Synchrotron., oxide, Absorption,
# Nearest to properties: Blöchl’s, strengths, nanoporous, plane, coordination, Zenobia, slope, characteristics,
# Nearest to all: Cp*W(NO)(H)(η1-CH2CH═CMe2)(PMe3).Welcome, platinum, essential, brute, vacancies, modeling, suitable, [Kerber,
# Nearest to on: degree, 4, solution., [Pt­(C^N)­(CN)2M­(PPh3)2]2, substance, based, spheres,, High-resolution,
# Nearest to DFT: electrocatalysts, change, produce, evaluated., Vienna, counterion, physics,, Photocatalysts,
# Nearest to based: catalysis,, Supporting, annealing, Pure-phase, unary,, is:, disorder, minimizes,
# Nearest to both: led, multi-frequency, Xu1,, QM9), sensing, remain, 0.3,, written,
# Nearest to For: interesting, convenience, accompanied, hcp, MEAM,, nm)., (0D), (https://github.com/vilab-tartu/SCAN),
# Nearest to the: package., Normal.py, resulting, (MatChS), ASTM, electronegativities,, Full, understood.,
# Average loss at step  32000 :  2.83035474449
# Average loss at step  34000 :  2.81169520187
# Average loss at step  36000 :  2.79839873379
# Average loss at step  38000 :  2.78967368811
# Average loss at step  40000 :  2.7777525
# Nearest to provide: enabling, Several, database:, certain, predictions., page, report, prevent,
# Nearest to using: SW480,, (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., coarse-grain, measurement, non-magnetic, (selected, article., constructed,
# Nearest to than: 2400, calibration, Au12,, generation, lower, estimate, (SBUs), Further,,
# Nearest to analysis: scripts, Compositions, Also, (1D), used.The, electrocatalysts, cyclometalated, article,,
# Nearest to well: distribution, applications., as, twin., connecting, access;, cohesion, Cubic,
# Nearest to a: broad, already, feasible,, inherently, photovoltaic, accompanies, blue, agree,
# Nearest to by: calculating, Award, XAS-Data-Interchange, resulting, achieved, compute, Starting, population,
# Nearest to values: Recommended, Australian, infra-red, Absorption, dataThis, provenance, Synchrotron., taken,
# Nearest to properties: Blöchl’s, strengths, nanoporous, plane, Zenobia, coordination, slope, fully-relativistic,
# Nearest to all: Cp*W(NO)(H)(η1-CH2CH═CMe2)(PMe3).Welcome, essential, vacancies, platinum, brute, With, modeling, shown.,
# Nearest to on: degree, 4, solution., based, substance, [Pt­(C^N)­(CN)2M­(PPh3)2]2, zip, automated,
# Nearest to DFT: electrocatalysts, evaluated., produce, counterion, change, exchange-correlation, Vienna, motifs,
# Nearest to based: catalysis,, Supporting, annealing, on, Pure-phase, data., scheme, disorder,
# Nearest to both: led, sensing, QM9), multi-frequency, Xu1,, adaptation, written, CH1,
# Nearest to For: interesting, accompanied, convenience, hcp, MEAM,, forces, 75, (https://github.com/vilab-tartu/SCAN),
# Nearest to the: (MatChS), enable, ASTM, Scientific, Normal.py, Full, adjacent, package.,
# Average loss at step  42000 :  2.76511383706
# Average loss at step  44000 :  2.76220721763
# Average loss at step  46000 :  2.76100687701
# Average loss at step  48000 :  2.74414566892
# Average loss at step  50000 :  2.74118263805
# Nearest to provide: enabling, database:, predictions., certain, page, Several, prevent, old,
# Nearest to using: SW480,, (selected, measurement, (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., article., coarse-grain, non-magnetic, (DFT),
# Nearest to than: 2400, calibration, generation, Au12,, lower, estimate, Further,, (SBUs),
# Nearest to analysis: scripts, Compositions, (1D), Also, cyclometalated, package., latex, added,
# Nearest to well: distribution, applications., as, connecting, twin., cohesion, You, access;,
# Nearest to a: broad, already, feasible,, photovoltaic, sum, agree, developing, Starting,
# Nearest to by: calculating, XAS-Data-Interchange, Award, resulting, compute, achieved, ligand,, Starting,
# Nearest to values: Recommended, Australian, infra-red, Absorption, dataThis, Synchrotron., provenance, separations,
# Nearest to properties: Blöchl’s, strengths, plane, nanoporous, slope, Zenobia, coordination, optimizations,
# Nearest to all: vacancies, Cp*W(NO)(H)(η1-CH2CH═CMe2)(PMe3).Welcome, platinum, essential, With, shown., modeling, suitable,
# Nearest to on: degree, solution., based, 4, [Pt­(C^N)­(CN)2M­(PPh3)2]2, substance, spheres,, automated,
# Nearest to DFT: electrocatalysts, change, counterion, evaluated., Photocatalysts, produce, API, exchange-correlation,
# Nearest to based: Supporting, catalysis,, annealing, on, disorder, data., Pure-phase, scheme,
# Nearest to both: multi-frequency, sensing, written, led, yield, QM9), CH1, Xu1,,
# Nearest to For: interesting, accompanied, hcp, convenience, forces, MEAM,, 75, (https://github.com/vilab-tartu/SCAN),
# Nearest to the: enable, Full, ASTM, (MatChS), sampled, testing, resulting, materials,,
# Average loss at step  52000 :  2.73794860345
# Average loss at step  54000 :  2.73916913044
# Average loss at step  56000 :  2.73124742472
# Average loss at step  58000 :  2.72313339537
# Average loss at step  60000 :  2.72272830951
# Nearest to provide: enabling, database:, page, prevent, predictions., certain, Several, old,
# Nearest to using: SW480,, measurement, (selected, coarse-grain, (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., (DFT), non-magnetic, article.,
# Nearest to than: 2400, generation, calibration, lower, Au12,, estimate, in.Octahedral, (SBUs),
# Nearest to analysis: Compositions, scripts, used.The, Also, cyclometalated, article,, (1D), throughput,
# Nearest to well: distribution, applications., as, connecting, twin., access;, main, You,
# Nearest to a: broad, already, feasible,, interrogate, photovoltaic, developing, agree, submitted,
# Nearest to by: calculating, ligand,, XAS-Data-Interchange, Award, resulting, compute, achieved, dominated,
# Nearest to values: Recommended, Australian, Absorption, infra-red, Synchrotron., taken, dataThis, provenance,
# Nearest to properties: Blöchl’s, strengths, nanoporous, plane, coordination, slope, Zenobia, 53,
# Nearest to all: vacancies, platinum, essential, modeling, Cp*W(NO)(H)(η1-CH2CH═CMe2)(PMe3).Welcome, brute, shown., environment,
# Nearest to on: degree, solution., 4, based, substance, [Pt­(C^N)­(CN)2M­(PPh3)2]2, zip, spheres,,
# Nearest to DFT: electrocatalysts, change, counterion, evaluated., produce, Vienna, Photocatalysts, API,
# Nearest to based: Supporting, annealing, catalysis,, data., on, minimizes, disorder, Pure-phase,
# Nearest to both: sensing, CH1, multi-frequency, adaptation, yield, QM9), written, led,
# Nearest to For: interesting, convenience, accompanied, hcp, 75, MEAM,, forces, (https://github.com/vilab-tartu/SCAN),
# Nearest to the: enable, distributions, electronegativities,, International, Full, package., ASTM, resulting,
# Average loss at step  62000 :  2.72410156953
# Average loss at step  64000 :  2.71713502914
# Average loss at step  66000 :  2.72258773637
# Average loss at step  68000 :  2.70883195966
# Average loss at step  70000 :  2.71690838099
# Nearest to provide: enabling, database:, prevent, predictions., page, Several, old, certain,
# Nearest to using: SW480,, (selected, article., coarse-grain, (DFT), (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., measurement, high-,
# Nearest to than: 2400, generation, calibration, lower, Au12,, (SBUs), estimate, in.Octahedral,
# Nearest to analysis: Compositions, scripts, Also, package., used.The, cyclometalated, article,, added,
# Nearest to well: as, applications., distribution, connecting, twin., You, access;, cohesion,
# Nearest to a: already, broad, feasible,, photovoltaic, interrogate, agree, sum, developing,
# Nearest to by: calculating, XAS-Data-Interchange, Award, ligand,, resulting, compute, highlights, achieved,
# Nearest to values: Recommended, Australian, Absorption, infra-red, Synchrotron., toxicity,, Instruments., taken,
# Nearest to properties: Blöchl’s, strengths, plane, nanoporous, Zenobia, slope, composites", 53,
# Nearest to all: vacancies, essential, platinum, modeling, Cp*W(NO)(H)(η1-CH2CH═CMe2)(PMe3).Welcome, brute, shown., With,
# Nearest to on: solution., 4, degree, based, [Pt­(C^N)­(CN)2M­(PPh3)2]2, substance, spheres,, zip,
# Nearest to DFT: electrocatalysts, change, counterion, evaluated., produce, API, Vienna, Photocatalysts,
# Nearest to based: Supporting, catalysis,, annealing, data., on, Pure-phase, disorder, scheme,
# Nearest to both: sensing, CH1, multi-frequency, adaptation, QM9), written, embrittling, yield,
# Nearest to For: interesting, accompanied, hcp, convenience, 75, forces, MEAM,, host,
# Nearest to the: enable, octahedra, articles, Projector, resulting, sampled, model., Scientific,
# Average loss at step  72000 :  2.71203790641
# Average loss at step  74000 :  2.70784860945
# Average loss at step  76000 :  2.70988073248
# Average loss at step  78000 :  2.70999496979
# Average loss at step  80000 :  2.70302104449
# Nearest to provide: enabling, page, database:, prevent, predictions., Several, old, certain,
# Nearest to using: SW480,, (selected, article., coarse-grain, (DFT), (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., improved, non-magnetic,
# Nearest to than: 2400, generation, lower, Au12,, calibration, estimate, Telescope, in.Octahedral,
# Nearest to analysis: Compositions, scripts, package., used.The, cyclometalated, (1D), widely-used, electrocatalysts,
# Nearest to well: applications., distribution, as, connecting, twin., You, cohesion, main,
# Nearest to a: broad, already, feasible,, sum, interrogate, photovoltaic, Starting, inherently,
# Nearest to by: calculating, XAS-Data-Interchange, ligand,, compute, Award, resulting, prohibit, achieved,
# Nearest to values: Recommended, Australian, Absorption, infra-red, Synchrotron., taken, Instruments., provenance,
# Nearest to properties: Blöchl’s, strengths, plane, slope, Zenobia, "The, nanoporous, composites",
# Nearest to all: vacancies, platinum, environment, find, brute, shown., With, 691,
# Nearest to on: solution., 4, [Pt­(C^N)­(CN)2M­(PPh3)2]2, based, degree, substance, spheres,, dawn,
# Nearest to DFT: electrocatalysts, counterion, change, API, evaluated., Photocatalysts, produce, Vienna,
# Nearest to based: Supporting, catalysis,, annealing, data., on, disorder, scheme, minimizes,
# Nearest to both: sensing, CH1, adaptation, multi-frequency, yield, written, Xu1,, separations,
# Nearest to For: interesting, accompanied, convenience, 75, hcp, forces, MEAM,, host,
# Nearest to the: International, distributions, sampled, resulting, favorable, bulk., model., octahedra,
# Average loss at step  82000 :  2.71358460933
# Average loss at step  84000 :  2.69662986106
# Average loss at step  86000 :  2.70164556789
# Average loss at step  88000 :  2.70192798203
# Average loss at step  90000 :  2.70053294313
# Nearest to provide: enabling, page, prevent, database:, Several, predictions., old, certain,
# Nearest to using: SW480,, (selected, (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., coarse-grain, measurement, article., improved, (DFT),
# Nearest to than: 2400, generation, lower, Au12,, calibration, estimate, more, in.Octahedral,
# Nearest to analysis: Compositions, scripts, cyclometalated, (1D), widely-used, added, package., (VASP),
# Nearest to well: as, applications., distribution, twin., connecting, You, biaxial, main,
# Nearest to a: broad, already, feasible,, interrogate, sum, photovoltaic, inherently, agree,
# Nearest to by: calculating, XAS-Data-Interchange, Award, ligand,, compute, dominated, resulting, highlights,
# Nearest to values: Recommended, Australian, infra-red, Absorption, taken, Synchrotron., provenance, Instruments.,
# Nearest to properties: Blöchl’s, strengths, composites", "The, plane, Zenobia, 53, CH1,
# Nearest to all: vacancies, platinum, environment, find, shown., essential, With, brute,
# Nearest to on: solution., spheres,, 4, degree, based, substance, [Pt­(C^N)­(CN)2M­(PPh3)2]2, zip,
# Nearest to DFT: electrocatalysts, counterion, change, evaluated., API, Photocatalysts, Vienna, produce,
# Nearest to based: annealing, catalysis,, Supporting, on, data., disorder, minimizes, scheme,
# Nearest to both: sensing, CH1, adaptation, yield, separations, embrittling, written, build,
# Nearest to For: accompanied, interesting, convenience, 75, hcp, forces, MEAM,, host,
# Nearest to the: International, Full, sampled, energetics, model., (MatChS), octahedra, convention,
# Average loss at step  92000 :  2.70269023162
# Average loss at step  94000 :  2.69752715087
# Average loss at step  96000 :  2.69280464864
# Average loss at step  98000 :  2.69954261541
# Average loss at step  100000 :  2.69868757021
# Nearest to provide: enabling, page, database:, prevent, predictions., Several, old, report,
# Nearest to using: SW480,, (selected, coarse-grain, (http://amdc.impcas.ac.cn/evaluation/data2012/ame.html)., article., (DFT), measurement, four,
# Nearest to than: 2400, generation, lower, Au12,, calibration, more, estimate, in.Octahedral,
# Nearest to analysis: cyclometalated, electrocatalysts, Compositions, article,, used.The, throughput, added, package.,
# Nearest to well: as, applications., distribution, twin., You, connecting, biaxial, 50%,
# Nearest to a: broad, feasible,, already, photovoltaic, sum, repository, interrogate, blue,
# Nearest to by: calculating, ligand,, resulting, XAS-Data-Interchange, dominated, Award, achieved, poorly,
# Nearest to values: Recommended, Absorption, infra-red, Australian, taken, Instruments., provenance, dataThis,
# Nearest to properties: Blöchl’s, strengths, plane, composites", determination, inputs, "The, Zenobia,
# Nearest to all: vacancies, platinum, essential, environment, brute, find, shown., Large,
# Nearest to on: degree, solution., substance, based, 4, [Pt­(C^N)­(CN)2M­(PPh3)2]2, spheres,, High-resolution,
# Nearest to DFT: electrocatalysts, counterion, change, Vienna, evaluated., Photocatalysts, API, produce,
# Nearest to based: Supporting, on, annealing, catalysis,, data., disorder, scheme, tools,,
# Nearest to both: sensing, CH1, yield, adaptation, written, multi-frequency, embrittling, separations,
# Nearest to For: convenience, accompanied, interesting, hcp, 75, forces, MEAM,, host,
# Nearest to the: International, consistently, distributions, enable, model., (https://www.iupac.org/publications/pac/83/2/0397/)., Full, operating,

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'MDF_2.png'))

except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)

# %%
v = read_data(filename)

# %%
len(np.unique(v))
# Out:
# 2849
